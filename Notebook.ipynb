# %% [markdown]
# # Exploratory Data Analysis of Computer Science Students' Academic Performance

# %%
# import libraries
import numpy as np
import pandas as pd

# %%
# loading the workbook into Jupyter Notebook environment
# File path and name of workbook
file_path_name = 'data/StudentRec_.xlsx'
data_workbook = pd.ExcelFile(file_path_name)

# %%
# listing the names of each table in the workbook
sheet_names = data_workbook.sheet_names
print(sheet_names)
# Out:
# ['Registration', 'Biodata', 'Result', 'Courses', 'CoursesII', 'Sheet1']

# %%
# Read all sheets into different dataframes using sheet names
for sheet_name in sheet_names:
    globals()[sheet_name] = pd.read_excel(file_path_name, sheet_name=sheet_name)

# %% [markdown]
# <br>
#
# ### Viewing each Table in the dataset

# %%
Registration.head(10)
# Out:
#    Matric Number    Session  Semester  Year
# 0              3  2000-2001         1   1.0
# 1              3  2000-2001         2   1.0
# 2              3  2002-2003         1   2.0
# 3              3  2002-2003         2   2.0
# 4              3  2003-2004         1   3.0
# 5              3  2003-2004         2   3.0
# 6              3  2005-2006         1   4.0
# 7              3  2005-2006         2   4.0
# 8              3  2006-2007         1   4.0
# 9              4  2000-2001         1   1.0

# %%
Biodata.head(10)
# Out:
#    MATRIC_NO     Sex Marital Status   Religion State of Origin Nationality  \
# 0          7  Female         Single  Christian            Osun    Nigerian
# 1          8    Male         Single  Christian             NaN    Nigerian
# 2          9    Male         Single     muslim           lagos    Nigerian
# 3         10  Female         Single  Christian             NaN    Nigerian
# 4         11    Male         Single  Christian             NaN    Nigerian
# 5         12  Female         Single  Christian             NaN    Nigerian
# 6         13    Male         Single  Christian             NaN    Nigerian
# 7         14  Female         Single  Christian             NaN    Nigerian
# 8         15  Female         Single  Christian            Ondo    Nigerian
# 9         16    Male         Single  Christian             NaN    Nigerian
#
#       YOA
# 0     NaN
# 1  2000.0
# 2  2000.0
# 3     NaN
# 4  2000.0
# 5  2000.0
# 6  2000.0
# 7  2000.0
# 8  2000.0
# 9  2000.0

# %%
Result.head(10)
# Out:
#    MATRIC_NO    Session  Semester Course Code Grade  Mark  Exam Unnamed: 7  \
# 0          1  2001-2002         2      CSC204   NaN   NaN  True          F
# 1          1  2001-2002         2      GST106   NaN   NaN  True          F
# 2          1  2001-2002         2      GST113   NaN   NaN  True          F
# 3          1  2001-2002         2      GST202   NaN   NaN  True          F
# 4          1  2001-2002         2      MAT202   NaN   NaN  True          F
# 5          1  2001-2002         2      MAT204     -   NaN  True          F
# 6          1  2001-2002         2      MAT207   NaN   NaN  True          F
# 7          1  2001-2002         2      PHS263   NaN   NaN  True          F
# 8          2  2001-2002         1      CSC201   NaN   NaN  True          F
# 9          2  2001-2002         1      GST102     F  33.0  True          F
#
#    Course_code_Key  Course_Unit
# 0  2001-2002CSC204          3.0
# 1  2001-2002GST106          2.0
# 2  2001-2002GST113          2.0
# 3  2001-2002GST202          2.0
# 4  2001-2002MAT202          2.0
# 5  2001-2002MAT204          2.0
# 6  2001-2002MAT207          2.0
# 7  2001-2002PHS263          2.0
# 8  2001-2002CSC201          3.0
# 9  2001-2002GST102          2.0

# %%
Courses.head(10)
# Out:
#   Course Code                                       Course Title  \
# 0      ACC210                           Principles of Accounting
# 1      ACC220                        Elements of Cost Accounting
# 2      ACC310                                                NaN
# 3      ACC320                            Management Accounting I
# 4      ACC421  Management Information Systems and Computer Ap...
# 5      ACS211                         Probability and Statistics
# 6      ACS310                                 Theory of Interest
# 7      ACS312                                Advance Mathematics
# 8      BIY302                                         Genetics 1
# 9      BIY402                                       Evolution II
#
#   Course Status Prerequisite  References  LevelSem Old_Status Old_Comp
# 0             o          NaN         NaN     200.0          1      NaN
# 1             o          NaN         NaN     200.0          1      NaN
# 2           NaN          NaN         NaN     300.0          E      NaN
# 3             o          NaN         NaN     300.0          1      NaN
# 4             e          NaN         NaN     400.0          1      NaN
# 5             o          NaN         NaN     200.0          1      NaN
# 6             o          NaN         NaN     300.0          1      NaN
# 7             o          NaN         NaN     300.0          1      NaN
# 8             e         none         NaN     300.0          1      NaN
# 9             e          NaN         NaN     400.0          1      NaN

# %%
CoursesII.head(10)
# Out:
#   Course Code                            Course Title Course Status  \
# 0      CSC100      Computer as a Problem-Solving Tool             c
# 1      CSC201          Principles of Computer Science             c
# 2      CSC202    Introduction to Computer Programming             c
# 3      CSC203      Foundations of Sequential Programs             c
# 4      CSC204      Data Structure and Data Management             c
# 5      CSC291           Industrial Training I (SIWES)             c
# 6      CSC301                              Algorithms             c
# 7      CSC302                  Concurrent Programming             c
# 8      CSC303  Analysis and Design of Digital Systems             c
# 9      CSC304                        Operating System             c
#
#      Prerequisite  Old_Comp  LevelSem  Semester  Units
# 0          FSC103       NaN       100         2      3
# 1             NaN       NaN       200         1      3
# 2             NaN       NaN       200         1      3
# 3             NaN       NaN       200         2      3
# 4             NaN       NaN       200         2      3
# 5             NaN       NaN       300         1      2
# 6             NaN       NaN       300         2      3
# 7             NaN       NaN       300         1      3
# 8          CSC203       NaN       300         1      3
# 9  CSC203, CSC204       NaN       300         1      3

# %%
Sheet1.head(10)
# Out:
#   Course_Code_Keys Course Code    Session  Semester  Units Lecturer ID  \
# 0  2001-2002ACC210      ACC210  2001-2002         2      3         NaN
# 1  1995-1996ACC220      ACC220  1995-1996         2      3         NaN
# 2  1997-1998ACC320      ACC320  1997-1998         2      3         NaN
# 3  1994-1995ACC421      ACC421  1994-1995         2      3         NaN
# 4  1997-1998ACS211      ACS211  1997-1998         1      3         NaN
# 5  1997-1998ACS310      ACS310  1997-1998         1      3         NaN
# 6  1997-1998ACS312      ACS312  1997-1998         1      3         NaN
# 7  1994-1995BIY302      BIY302  1994-1995         2      4         NaN
# 8  1994-1995BIY402      BIY402  1994-1995         1      2         NaN
# 9  1994-1995BIY408      BIY408  1994-1995         1      2         NaN
#
#    Exam Date  DupFlag
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# 5        NaN      NaN
# 6        NaN      NaN
# 7        NaN      NaN
# 8        NaN      NaN
# 9        NaN      NaN

# %% [markdown]
# ## Data Cleaning and Preprocessing

# %% [markdown]
# ### The Registration Data

# %%
Registration.head(10)
# Out:
#    Matric Number    Session  Semester  Year
# 0              3  2000-2001         1   1.0
# 1              3  2000-2001         2   1.0
# 2              3  2002-2003         1   2.0
# 3              3  2002-2003         2   2.0
# 4              3  2003-2004         1   3.0
# 5              3  2003-2004         2   3.0
# 6              3  2005-2006         1   4.0
# 7              3  2005-2006         2   4.0
# 8              3  2006-2007         1   4.0
# 9              4  2000-2001         1   1.0

# %% [markdown]
# #### Data types

# %%
Registration.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13422 entries, 0 to 13421
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Matric Number  13422 non-null  int64
#  1   Session        13422 non-null  object
#  2   Semester       13422 non-null  int64
#  3   Year           13419 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 419.6+ KB

# %% [markdown]
# <br>
#
# The `Year` Column denotes the level of the student and should therefore be in integer form. It will therefore be converted to Interger.
#
#
# Before going on to convert the Year column to integer, it is important to check for missing values and handle them appropriately
#
#
# #### Missing Values

# %%
Registration.isnull().sum()
# Out:
# Matric Number    0
# Session          0
# Semester         0
# Year             3
# dtype: int64

# %%
# Dropping all null entries which all appeared in the Year column and are three in number
Registration.dropna(inplace=True)

# %%
# Checking to see if null values have been dropped
Registration.isnull().sum()
# Out:
# Matric Number    0
# Session          0
# Semester         0
# Year             0
# dtype: int64

# %%
# Converting the Year column to integer
Registration['Year'] = Registration['Year'].astype(int)

# checking the dataframe
Registration.head()
# Out:
#    Matric Number    Session  Semester  Year
# 0              3  2000-2001         1     1
# 1              3  2000-2001         2     1
# 2              3  2002-2003         1     2
# 3              3  2002-2003         2     2
# 4              3  2003-2004         1     3

# %% [markdown]
# <br>
#
# Since the Registration table contains data of students that registered in each semester during their programme, it is expected that each matric number repeats at least 8 times each for students who completed the programme. Any Matric number that occured less than 8 times will be dropped as those students are assumed to either dropped out or transferred to another programme and will not be considered in this analysis.

# %%
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Converting the Year column to integer
# ----> 2 Registration['Year'] = Registration['Year'].astype(int)
#       4 # checking the dataframe
#       5 Registration.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:146, in _astype_float_to_int_nansafe(values, dtype, copy)
#     142 """
#     143 astype with a check preventing converting NaN to an meaningless integer value.
#     144 """
#     145 if not np.isfinite(values).all():
# --> 146     raise IntCastingNaNError(
#     147         "Cannot convert non-finite values (NA or inf) to integer"
#     148     )
#     149 if dtype.kind == "u":
#     150     # GH#45151
#     151     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer
